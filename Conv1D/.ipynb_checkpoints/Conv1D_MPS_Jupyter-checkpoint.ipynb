100
# 80/80 [==============================] - 17s 217ms/step - loss: 2.0938e-04 - mean_squared_error: 2.0938e-04 - val_loss: 3.0323e-04 - val_mean_squared_error: 3.0323e-04
# Epoch 83/100
# 80/80 [==============================] - 17s 215ms/step - loss: 2.0504e-04 - mean_squared_error: 2.0504e-04 - val_loss: 3.0266e-04 - val_mean_squared_error: 3.0266e-04
# Epoch 84/100
# 80/80 [==============================] - 17s 216ms/step - loss: 2.0091e-04 - mean_squared_error: 2.0091e-04 - val_loss: 2.9393e-04 - val_mean_squared_error: 2.9393e-04
# Epoch 85/100
# 80/80 [==============================] - 17s 216ms/step - loss: 1.9901e-04 - mean_squared_error: 1.9901e-04 - val_loss: 3.0332e-04 - val_mean_squared_error: 3.0332e-04
# Epoch 86/100
# 80/80 [==============================] - 19s 232ms/step - loss: 1.9988e-04 - mean_squared_error: 1.9988e-04 - val_loss: 3.0087e-04 - val_mean_squared_error: 3.0087e-04
# Epoch 87/100
# 80/80 [==============================] - 17s 217ms/step - loss: 1.9979e-04 - mean_squared_error: 1.9979e-04 - val_loss: 2.9980e-04 - val_mean_squared_error: 2.9980e-04
# Epoch 88/100
# 80/80 [==============================] - 17s 218ms/step - loss: 2.0089e-04 - mean_squared_error: 2.0089e-04 - val_loss: 3.0612e-04 - val_mean_squared_error: 3.0612e-04
# Epoch 89/100
# 80/80 [==============================] - 17s 219ms/step - loss: 2.0155e-04 - mean_squared_error: 2.0155e-04 - val_loss: 3.0209e-04 - val_mean_squared_error: 3.0209e-04
# Epoch 90/100
# 80/80 [==============================] - 18s 220ms/step - loss: 1.9987e-04 - mean_squared_error: 1.9987e-04 - val_loss: 2.9606e-04 - val_mean_squared_error: 2.9606e-04
# Epoch 91/100
# 80/80 [==============================] - 19s 234ms/step - loss: 1.9658e-04 - mean_squared_error: 1.9658e-04 - val_loss: 3.0344e-04 - val_mean_squared_error: 3.0344e-04
# Epoch 92/100
# 80/80 [==============================] - 17s 216ms/step - loss: 1.9931e-04 - mean_squared_error: 1.9931e-04 - val_loss: 2.9584e-04 - val_mean_squared_error: 2.9584e-04
# Epoch 93/100
# 80/80 [==============================] - 17s 216ms/step - loss: 1.9464e-04 - mean_squared_error: 1.9464e-04 - val_loss: 3.0447e-04 - val_mean_squared_error: 3.0447e-04
# Epoch 94/100
# 80/80 [==============================] - 18s 219ms/step - loss: 1.9785e-04 - mean_squared_error: 1.9785e-04 - val_loss: 3.0605e-04 - val_mean_squared_error: 3.0605e-04
# Epoch 95/100
# 80/80 [==============================] - 19s 232ms/step - loss: 1.9601e-04 - mean_squared_error: 1.9601e-04 - val_loss: 2.9876e-04 - val_mean_squared_error: 2.9876e-04
# Epoch 96/100
# 80/80 [==============================] - 17s 217ms/step - loss: 1.9311e-04 - mean_squared_error: 1.9311e-04 - val_loss: 3.0295e-04 - val_mean_squared_error: 3.0295e-04
# Epoch 97/100
# 80/80 [==============================] - 17s 216ms/step - loss: 1.9229e-04 - mean_squared_error: 1.9229e-04 - val_loss: 3.0151e-04 - val_mean_squared_error: 3.0151e-04
# Epoch 98/100
# 80/80 [==============================] - 18s 223ms/step - loss: 1.9240e-04 - mean_squared_error: 1.9240e-04 - val_loss: 3.0714e-04 - val_mean_squared_error: 3.0714e-04
# Epoch 99/100
# 80/80 [==============================] - 18s 230ms/step - loss: 1.9187e-04 - mean_squared_error: 1.9187e-04 - val_loss: 3.0574e-04 - val_mean_squared_error: 3.0574e-04
# Epoch 100/100
# 80/80 [==============================] - 17s 216ms/step - loss: 1.9333e-04 - mean_squared_error: 1.9333e-04 - val_loss: 3.1057e-04 - val_mean_squared_error: 3.1057e-04

# %% [markdown]
# Save the trained model

# %%
#model_conv1D.save('Conv1D') # save as pb
model_conv1D.save("Conv1D_MPS.h5") # save as h5 (used in Keras)

# %% [markdown]
# ### 6. Plot the training result

# %%
def printHistory(history):
       loss_curve = history.history["loss"]
       mse_curve = history.history["mean_squared_error"]

       loss_dev_curve = history.history["val_loss"]
       mse_dev_curve = history.history["val_mean_squared_error"]

       fig1, axs1 = plt.subplots(figsize=(14,6))
       axs1.plot(mse_curve, color='royalblue', alpha = 1, linewidth=3.0, label="Train")
       axs1.plot(mse_dev_curve, color='red', alpha = 1, linewidth=3.0, label="Dev")
       axs1.set_ylabel('Mean Squared Error', fontsize=20)
       axs1.set_xlabel('Epoch', fontsize=20)
       axs1.grid(color='g', ls = '-.', lw = 0.3)
       plt.xticks(fontsize = 16)
       plt.yticks(fontsize = 16)
       plt.legend(loc='lower right', fontsize=20)
       plt.show()
       
       fig2, axs2 = plt.subplots(figsize=(14,6))
       axs2.plot(mse_curve, color='royalblue', alpha = 1, linewidth=3.0, label="loss")
       axs2.plot(mse_dev_curve, color='red', alpha = 1, linewidth=3.0, label="val_loss")
       axs2.set_ylabel('Mean Squared Error', fontsize=20)
       axs2.set_yscale('log')
       axs2.set_xlabel('Epoch', fontsize=20)
       axs2.grid(color='g', ls = '-.', lw = 0.3)
       plt.xticks(fontsize = 16)
       plt.yticks(fontsize = 16)
       plt.legend(loc='lower right', fontsize=20)
       plt.show()
printHistory(history)

# %% [markdown]
# ### 7. Evaluate the Inference Speed

# %% [markdown]
# Load the model

# %%
model_1D = load_model("Conv1D_MPS.h5")

# %% [markdown]
# Calculate the inference speed by averaging 1000 inference.

# %%
def InferenceSpeed(model):
    start = time.time()
    for i in range(1000):
        inputData = X[i].reshape((1, X[i].shape[0]))
        inputData = np.reshape(inputData, (inputData.shape[0], inputData.shape[1], 1))
        prediction = model.predict(inputData)
    end = time.time()
    return "Inference speed = " + str((end-start)/1000) + " s"

print(InferenceSpeed(model_1D))
# Out:
# Inference speed = 0.031276156187057494 s

# %% [markdown]
# ### 8. Accuracy on Test Set

# %% [markdown]
# Evaluate the performance by predicting on test set (simulated data).

# %%
def TestSetAccuracy(model):
    total = 0
    for i in range(X_test.shape[0]):
        inputData = X_test[i].reshape((1, X_test[i].shape[0]))
        inputData = np.reshape(inputData, (inputData.shape[0], inputData.shape[1], 1))
        prediction = model.predict(inputData)
        total += np.square(np.subtract(y_test[i].reshape((1, y_test[i].shape[0])), prediction)).mean()
    return "Mean Sqaure Error = " + str(total/X_test.shape[0])

print(TestSetAccuracy(model_1D))
# Out:
# Mean Sqaure Error = 0.00026713289955728397

# %% [markdown]
# Evaluate the performance by predicting on test set (real data).

# %%
dataset1_CF = scipy.io.loadmat('E:\Stanford_Autumn_2021\CS_230\Project\Dataset\Data_CF\Data_CF\X_signal\AF_signal.mat')
labelset1_CF = scipy.io.loadmat('E:\Stanford_Autumn_2021\CS_230\Project\Dataset\Data_CF\Data_CF\Y_MPS\AF_Y.mat')
labelset1_2_CF = scipy.io.loadmat('E:\Stanford_Autumn_2021\CS_230\Project\Dataset\Data_CF\Data_CF\Y_MPSR\AF_Y.mat')
dataset2_CF  = scipy.io.loadmat('E:\Stanford_Autumn_2021\CS_230\Project\Dataset\Data_CF\Data_CF\X_signal\PAC_signal.mat')
labelset2_CF = scipy.io.loadmat('E:\Stanford_Autumn_2021\CS_230\Project\Dataset\Data_CF\Data_CF\Y_MPS\PAC_Y.mat')
labelset2_2_CF = scipy.io.loadmat('E:\Stanford_Autumn_2021\CS_230\Project\Dataset\Data_CF\Data_CF\Y_MPSR\PAC_Y.mat')

zeros = np.zeros((50,8,dataset1_CF['signal_matrix'].shape[2]))
dataset1_CF = np.concatenate((zeros, dataset1_CF['signal_matrix']), axis=0)
dataset1_CF = np.concatenate((dataset1_CF, zeros), axis=0)
input_matrix_CF = np.concatenate((dataset1_CF, dataset2_CF['signal_matrix']), axis=2).T
X_CF = input_matrix_CF.reshape(input_matrix_CF.shape[0],-1)

label_CF = np.concatenate((labelset1_CF['label'], labelset2_CF['label']), axis=0)

zeros = np.zeros((50,8,dataset1_CF['signal_matrix'].shape[2]))
dataset1_CF_2 = np.concatenate((zeros, dataset1_CF['signal_matrix']), axis=0)
dataset1_CF_2 = np.concatenate((dataset1_CF_2, zeros), axis=0)
input_matrix_CF_2 = np.concatenate((dataset1_CF_2, dataset2_CF['signal_matrix']), axis=2).T
X_CF_2 = input_matrix_CF_2.reshape(input_matrix_CF_2.shape[0],-1)

label_CF_2 = np.concatenate((labelset1_2_CF['label'], labelset2_2_CF['label']), axis=0)


dataset1_MMA = scipy.io.loadmat('E:\Stanford_Autumn_2021\CS_230\Project\Dataset\Data_MMA\Data_MMA\X_signal\MMA_1_signal.mat')
labelset1_MMA = scipy.io.loadmat('E:\Stanford_Autumn_2021\CS_230\Project\Dataset\Data_MMA\Data_MMA\Y_MPS\MMA_1_Y.mat')
labelset1_2_MMA = scipy.io.loadmat('E:\Stanford_Autumn_2021\CS_230\Project\Dataset\Data_MMA\Data_MMA\Y_MPSR\MMA_1_Y.mat')
dataset2_MMA = scipy.io.loadmat('E:\Stanford_Autumn_2021\CS_230\Project\Dataset\Data_MMA\Data_MMA\X_signal\MMA_2_signal.mat')
labelset2_MMA = scipy.io.loadmat('E:\Stanford_Autumn_2021\CS_230\Project\Dataset\Data_MMA\Data_MMA\Y_MPS\MMA_2_Y.mat')
labelset2_2_MMA = scipy.io.loadmat('E:\Stanford_Autumn_2021\CS_230\Project\Dataset\Data_MMA\Data_MMA\Y_MPSR\MMA_2_Y.mat')

input_matrix_MMA = np.concatenate((dataset1_MMA['signal_matrix'], dataset2_MMA['signal_matrix']), axis=2).T
X_MMA = input_matrix_MMA.reshape(input_matrix_MMA.shape[0],-1)

label_MMA = np.concatenate((labelset1_MMA['label'], labelset2_MMA['label']), axis=0)

input_matrix_MMA_2 = np.concatenate((dataset1_MMA['signal_matrix'], dataset2_MMA['signal_matrix']), axis=2).T
X_MMA_2 = input_matrix_MMA_2.reshape(input_matrix_MMA_2.shape[0],-1)

label_MMA_2 = np.concatenate((labelset1_2_MMA['label'], labelset2_2_MMA['label']), axis=0)



total = 0
for i in range(X_CF.shape[0]):
    inputData = X_CF[i].reshape((1, X_CF[i].shape[0]))
    inputData = np.reshape(inputData, (inputData.shape[0], inputData.shape[1], 1))
    prediction = model_1D.predict(inputData)
    total += np.square(np.subtract(label_CF[i].reshape((1, label_CF[i].shape[0])), prediction)).mean()
print("Mean Sqaure Error = " + str(total/X_CF.shape[0]))
scipy.io.savemat("CF_MPS_prediction.mat", prediction)

total = 0
for i in range(X_CF_2.shape[0]):
    inputData = X_CF_2[i].reshape((1, X_CF_2[i].shape[0]))
    inputData = np.reshape(inputData, (inputData.shape[0], inputData.shape[1], 1))
    prediction = model_1D_2.predict(inputData)
    total += np.square(np.subtract(label_CF_2[i].reshape((1, label_CF_2[i].shape[0])), prediction)).mean()
print("Mean Sqaure Error = " + str(total/X_CF_2.shape[0]))
scipy.io.savemat("CF_MPSR_prediction.mat", prediction)

total = 0
for i in range(X_MMA.shape[0]):
    inputData = X_MMA[i].reshape((1, X_MMA[i].shape[0]))
    inputData = np.reshape(inputData, (inputData.shape[0], inputData.shape[1], 1))
    prediction = model_1D.predict(inputData)
    total += np.square(np.subtract(label_MMA[i].reshape((1, label_MMA[i].shape[0])), prediction)).mean()
print("Mean Sqaure Error = " + str(total/X_MMA.shape[0]))
scipy.io.savemat("MMA_MPS_prediction.mat", prediction)

total = 0
for i in range(X_MMA_2.shape[0]):
    inputData = X_MMA_2[i].reshape((1, X_MMA_2[i].shape[0]))
    inputData = np.reshape(inputData, (inputData.shape[0], inputData.shape[1], 1))
    prediction = model_1D_2.predict(inputData)
    total += np.square(np.subtract(label_MMA_2[i].reshape((1, label_MMA_2[i].shape[0])), prediction)).mean()
print("Mean Sqaure Error = " + str(total/X_MMA_2.shape[0]))
scipy.io.savemat("MMA_MPSR_prediction.mat", prediction)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-f741115aac7d> in <module>
#      14 label_CF = np.concatenate((labelset1_CF['label'], labelset2_CF['label']), axis=0)
#      15
# ---> 16 zeros = np.zeros((50,8,dataset1_CF['signal_matrix'].shape[2]))
#      17 dataset1_CF_2 = np.concatenate((zeros, dataset1_CF['signal_matrix']), axis=0)
#      18 dataset1_CF_2 = np.concatenate((dataset1_CF_2, zeros), axis=0)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
